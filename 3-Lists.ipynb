# %% [markdown]
# # list

# %%
myString = "hello python"

# %%
myString
# Out:
# 'hello python'

# %%
myString[0]
# Out:
# 'h'

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
print(myList[0] + myList[1] + myList[2])
# Out:
# 60

# %%
myList = ["x","y","z"]

# %%
myList
# Out:
# ['x', 'y', 'z']

# %%
type(myList[0])
# Out:
# str

# %%
myList[0] = 100

# %%
myList
# Out:
# [100, 'y', 'z']

# %%
myList[len(myList)-1]
# Out:
# 'z'

# %%
myList[-1]
# Out:
# 'z'

# %%
myList[-2]
# Out:
# 'y'

# %%
myList.append(80)

# %%
myList
# Out:
# [100, 'y', 'z', 80]

# %%
myList.append(1)

# %%
myList
# Out:
# [100, 'y', 'z', 80, 1]

# %%
myList.pop()
# Out:
# 1

# %%
myList
# Out:
# [100, 'y', 'z', 80]

# %%
myList.count("y")
# Out:
# 1

# %%
myList.index("z")
# Out:
# 2

# %%
myList.insert(0, 200)

# %%
myList.insert(len(myList), 500)

# %%
myList
# Out:
# [200, 100, 'y', 'z', 80, 500]

# %%
myList.remove(100)

# %%
myList
# Out:
# [200, 'y', 'z', 80, 500]

# %%
myList.reverse()

# %%
myList
# Out:
# [500, 80, 'z', 'y', 200]

# %%
myList.remove("z")

# %%
myList.remove("y")

# %%
myList
# Out:
# [500, 80, 200]

# %%
myList.sort()

# %%
myList
# Out:
# [80, 200, 500]

# %%
x = input("enter x")
# Out:
# enter x 5

# %%
x
# Out:
# '5'

# %%
type(x)
# Out:
# str

# %%
y = input("enter y: ")
# Out:
# enter y:  10

# %%
z = input("enter z: ")
# Out:
# enter z:  15

# %%
inputList = []

# %%
type(inputList)
# Out:
# list

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# ['5', '10', '15']

# %%
myInteger = 50

# %%
str(myInteger)
# Out:
# '50'

# %%
myString = "40"

# %%
int(myString)
# Out:
# 40

# %%
float(myString)
# Out:
# 40.0

# %%
myString = "python"

# %%
#int(myString)

# %%
inputList
# Out:
# ['5', '10', '15']

# %%
int(inputList[1]) * 2
# Out:
# 20

# %%
inputList
# Out:
# ['5', '10', '15']

# %%
nameList = ["Oğuz", "Batuhan"]

# %%
type(nameList)
# Out:
# list

# %%
nameList
# Out:
# ['Oğuz', 'Batuhan']

# %%
mixeList = ["Oğuz", "10", "2.5"]

# %%
mixeList
# Out:
# ['Oğuz', '10', '2.5']

# %%
list1 = [10, 20, 30]

# %%
list2 = [40, 50, 60]

# %%
list1 + list2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1 * 2
# Out:
# [10, 20, 30, 10, 20, 30]

# %% [markdown]
# ## nestedList

# %%
myNestedList = [10, 20, 3.14, "Oğuz", [1,2,3]]

# %%
myNestedList[4][1]
# Out:
# 2

# %%
lastList = ["a", "b", ["c", "d", "e"], "f"]

# %%
len(lastList)
# Out:
# 4

# %%
len(lastList) + len(lastList[2])
# Out:
# 7

# %%
lastList[2]
# Out:
# ['c', 'd', 'e']

# %%
lastList[2][0]
# Out:
# 'c'

# %%
firstList = [10,20,30,40,50,60,70]

# %%
firstList[::]
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
firstList[2::]
# Out:
# [30, 40, 50, 60, 70]

# %%
firstList[:5:]
# Out:
# [10, 20, 30, 40, 50]

# %%
firstList[::2]
# Out:
# [10, 30, 50, 70]

# %%
firstList[1:6:2]
# Out:
# [20, 40, 60]
