# %%
False and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True & False # and
# Out:
# False

# %%
True | False # or
# Out:
# True

# %%
not 1 == 1
# Out:
# False

# %%
not 1 == 2
# Out:
# True

# %%
10 in [10, 20, 30]
# Out:
# True

# %%
10 not in [10, 20, 30]
# Out:
# False

# %%
40 not in [10, 20, 30]
# Out:
# True

# %%
10 in {10, 20}
# Out:
# True

# %%
10 in {"a":10, "b":20}.values()
# Out:
# True

# %%
"a" in {"a":10, "b":20}
# Out:
# True

# %%
"a" in {"a":10, "b":20}.keys()
# Out:
# True

# %%
my_superhero = "Batman"

# %%
if my_superhero == "Batman":
    print("Batmannn")
    print("Oğuz Batuhan")
# Out:
# Batmannn
# Oğuz Batuhan

# %%
if my_superhero == "Superman":
    print("Batmannn")
    print("Oğuz Batuhan")

# %%
if my_superhero == "Superman":
    print("Batmannn")
    print("Oğuz Batuhan")
print("Hello Python")
# Out:
# Hello Python

# %%
my_superhero = input("Enter superhero: ")
# Out:
# Enter superhero:  Wonder women

# %%
if my_superhero == "superman":
    print("superman")
elif my_superhero == "batman":
    print("batman")
elif my_superhero == "Harley Quinn":
    print("Harley Quinn")
# Out:
# Harley Quinn

# %%
if my_superhero == "superman":
    print("superman")
elif my_superhero == "batman":
    print("batman")
elif my_superhero == "Harley Quinn":
    print("Harley Quinn")
else: print(":(")
# Out:
# :(

# %%
my_superhero = input("Enter superhero: ")
# Out:
# Enter superhero:  Spider Man

# %%
my_superhero_list = ["Spider Man", "Iron Man", "Thor", "Black Window"]

# %%
if my_superhero in my_superhero_list:
    print(":)")
else: print (":(")
# Out:
# :)
