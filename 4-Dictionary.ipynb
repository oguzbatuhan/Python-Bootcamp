# %% [markdown]
# # Dictionary

# %% [markdown]
# key - value pairing

# %%
fruit_list = ["banana", "apple"]

# %%
calorie_list = [100, 150]

# %%
print(str(fruit_list[0]) + " " + str(calorie_list[0]))
# Out:
# banana 100

# %%
fitness_dictionary = {"banana":100, "apple":150}

# %%
type(fitness_dictionary)
# Out:
# dict

# %%
fitness_dictionary["banana"]
# Out:
# 100

# %%
fitness_dictionary.keys()
# Out:
# dict_keys(['banana', 'apple'])

# %%
fitness_dictionary.values()
# Out:
# dict_values([100, 150])

# %%
type(fitness_dictionary.values())
# Out:
# dict_values

# %%
type(fitness_dictionary.keys())
# Out:
# dict_keys

# %%
fitness_list = list(fitness_dictionary.values())

# %%
(fitness_list[0] + fitness_list[1])/2
# Out:
# 125.0

# %%
fitness_dictionary
# Out:
# {'banana': 100, 'apple': 150}

# %%
fitness_dictionary["banana"] = 200

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150}

# %%
fitness_dictionary["melon"] = 300

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150, 'melon': 300}

# %%
help(fitness_dictionary.get)
# Out:
# Help on built-in function get:
#
# get(key, default=None, /) method of builtins.dict instance
#     Return the value for key if key is in the dictionary, else default.

# %%
fitness_dictionary.get("app", 0)
# Out:
# 0

# %%
my_dictionary = {100:"a", 200:"b", 300:"c"}

# %%
my_dictionary[100]
# Out:
# 'a'

# %%
my_dictionary[100] + my_dictionary[200]
# Out:
# 'ab'

# %%
my_dictionary = {"key1":"value1", "key2":"value2", "key3":"value3"}

# %%
my_dictionary["key3"]
# Out:
# 'value3'

# %%
my_mixed_dictionary = {"ke1":100, "key2":3.14, "key3":[10,20,30,40,50,60,70]}

# %%
my_mixed_dictionary["key3"][1]
# Out:
# 20

# %%
last_dictionary = {"k1":10, "k2":"string", "k3":{"k1":[10, 20, {"k1":2, "k2":3, "k3":"finish"}]}}

# %%
last_dictionary["k3"]["k1"][2]["k3"]
# Out:
# 'finish'
