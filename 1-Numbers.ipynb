# %% [markdown]
# Variables

# %%
# int -> integer

# %%
5*2
# Out:
# 10

# %%
type(9)
# Out:
# int

# %%
type(5-2)
# Out:
# int

# %%
type(5+2)
# Out:
# int

# %%
# float -> floating point

# %%
5/2
# Out:
# 2.5

# %%
type(5/2)
# Out:
# float

# %%
type(.0*4)
# Out:
# float

# %%
pi=3.14

# %%
x=-100

# %%
pi*x
# Out:
# -314.0

# %%
# camelCase -> myName
# snake_case -> my_name
# PascalCase -> MyName
# kebap-case -> my-name

# %%
startCamp = "start on September 1, 2026"

# %%
myPythonCamp = "My python learning camp"

# %%
myEnglishCamp = "English learning camp (Busuu)"

# %%
myCamp = myPythonCamp + " and " + myEnglishCamp + " " + startCamp + "."

# %%
myCamp
# Out:
# 'My python learning camp and English learning camp (Busuu) start on September 1, 2026.'
