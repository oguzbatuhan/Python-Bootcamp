# %% [markdown]
# # Boolean

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBoolean = True

# %%
type(myBoolean)
# Out:
# bool

# %%
5 > 3
# Out:
# True

# %%
2 > 5
# Out:
# False

# %%
age = input("input age: ")
# Out:
# input age:  22

# %%
int(age) > 18
# Out:
# True
