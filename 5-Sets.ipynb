# %% [markdown]
# # Sets

# %% [markdown]
# unique elements, unordered

# %%
myList = [10,20,30,10,20,40,10,20,40]

# %%
len(myList)
# Out:
# 9

# %%
mySet = set(myList)

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet = {10,20,20,30,30,"a","a"}

# %%
mySet
# Out:
# {10, 20, 30, 'a'}

# %%
type(mySet)
# Out:
# set

# %%
mySet2 = {10, 20, 70, 80}

# %%
mySet.intersection(mySet2)
# Out:
# {10, 20}

# %%
mySet.union(mySet2)
# Out:
# {10, 20, 30, 70, 80, 'a'}

# %%
countryList = ["tr", "de", "tr", "tr", "fr", "fr", "fl", "de"]

# %%
len(set(countryList))
# Out:
# 4

# %%
emptySet = {}

# %%
type(emptySet)
# Out:
# dict

# %%
emptySet = set()

# %%
type(emptySet)
# Out:
# set

# %%
len(emptySet)
# Out:
# 0

# %%
emptySet.add(10)
emptySet.add(20)
emptySet.add(30)
emptySet.add(40)
emptySet.add("a")
emptySet.add("b")

# %%
emptySet
# Out:
# {10, 20, 30, 40, 'a', 'b'}

# %%
emptyList = list()

# %%
emptyList.append(10)
emptyList.append(10)
emptyList.append(20)
emptyList.append(30)
emptyList.append(30)

# %%
emptyList
# Out:
# [10, 10, 20, 30, 30]

# %%
emptyDictionary = dict()

# %%
emptyDictionary["a"]= 10

# %%
emptyDictionary["b"]= "c"

# %%
emptyDictionary
# Out:
# {'a': 10, 'b': 'c'}
