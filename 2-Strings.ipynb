# %% [markdown]
# # string

# %%
"Hello, World!"
# Out:
# 'Hello, World!'

# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %%
name = "Oğuz Batuhan"

# %%
type(name)
# Out:
# str

# %%
# str -> string

# %%
print(name)
# Out:
# Oğuz Batuhan

# %%
name.capitalize()
# Out:
# 'Oğuz batuhan'

# %%
name.capitalize
# Out:
# <function str.capitalize()>

# %%
x = 10

# %%
name.lower()
# Out:
# 'oğuz batuhan'

# %%
name.title()
# Out:
# 'Oğuz Batuhan'

# %%
help(name.count)
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice
#     notation.

# %%
help(name.capitalize)
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the
#     rest lower case.

# %%
name.count("a")
# Out:
# 2

# %%
name = name.upper()

# %%
name
# Out:
# 'OĞUZ BATUHAN'

# %%
len(name)
# Out:
# 12

# %%
print("Oğuz \nBatuhan")
# Out:
# Oğuz
# Batuhan

# %%
# \n -> new line

# %% [markdown]
# # index

# %%
myString = "hello python"

# %%
myString[4]
# Out:
# 'o'

# %%
myString[2]
# Out:
# 'l'

# %%
len(myString)
# Out:
# 12

# %%
myString[len(myString)-1]
# Out:
# 'n'

# %%
myString[-1]
# Out:
# 'n'

# %%
myString[-2]
# Out:
# 'o'

# %%
barcode = "ABCDE123152635"

# %%
print("A" + "B")
# Out:
# AB

# %%
name = "Oğuz Batuhan"

# %%
surname = "Çözeli"

# %%
fullname = name + " " + surname

# %%
print(fullname)
# Out:
# Oğuz Batuhan Çözeli

# %%
fullname * 5
# Out:
# 'Oğuz Batuhan ÇözeliOğuz Batuhan ÇözeliOğuz Batuhan ÇözeliOğuz Batuhan ÇözeliOğuz Batuhan Çözeli'

# %%
100 * "a"
# Out:
# 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa'

# %%
print(barcode[0] + barcode[1] + barcode[2])
# Out:
# ABC

# %% [markdown]
# ## slicing, starting index, stopping index, stepping size

# %%
#barcode[starting index:stopping index:stepping size]

# %%
print(barcode)
# Out:
# ABCDE123152635

# %%
barcode[0:3:]
# Out:
# 'ABC'

# %%
barcode[0::2]
# Out:
# 'ACE2123'

# %%
barcode[3::]
# Out:
# 'DE123152635'

# %%
barcode[3:5:]
# Out:
# 'DE'

# %%
barcode[::-1]
# Out:
# '536251321EDCBA'

# %%
name = "Oğuz Batuhan"

# %%
help(name.index)
# Out:
# Help on built-in function index:
#
# index(sub[, start[, end]], /) method of builtins.str instance
#     Return the lowest index in S where substring sub is found, such that sub is contained within S[start:end].
#
#     Optional arguments start and end are interpreted as in slice
#     notation.  Raises ValueError when the substring is not found.

# %%
name.index("a")
# Out:
# 6

# %%
name.split(" ")
# Out:
# ['Oğuz', 'Batuhan']

# %%
type(name.split())
# Out:
# list
